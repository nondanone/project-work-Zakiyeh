# %% [markdown]
# ###   <div style="text-align: left"> This Notebook works as the supplementary file for the paper:<div>
#
# ### <div style="text-align: justify"> Mass transport analysis of non-Newtonian fluids under combined electroosmotically and pressure driven flow in rectangular microreactors<div>
# <div style="text-align: jusfify">https://doi.org/10.1016/j.colsurfa.2016.08.023<div>

# %% [markdown]
# ### <div style="text-align: left"> You can find more information about Sharif University of Technology [here.](http://www.en.sharif.edu/)<div>

# %% [markdown]
# ### Abstract
#
# <div style="text-align: justify"> Hydrodynamically fully developed flow of power-law fluids under combined action of electroosmotic and pressure gradient forces in rectangular microreactors is analyzed considering heterogeneous catalytic reactions. The Poisson-Boltzmann, Cauchy momentum, and concentration equations are considered in two dimensions and after being dimensionless are numerically solved applying a finite difference algorithm. Variation of axial concentration gradient, and axial and horizontal mass diffusions are taken intoaccount as well. To accomplish a more general analysis, the velocity distribution is obtained by solving continuity and Cauchy momentum equations and is not considered as an average axial velocity for solving the concentration equation. Profiles of mean concentration of reactants are analyzed as functions of operating variables. Results reveal that mean concentration increases with increasing Péclet number and dimensionless Debye-Hückel parameter. It is also a decreasing function of Damkohler number. Presence of pressure gradient will affect the decreasing trend of mean concentration through the channel. Shear-thinning fluids, due to their nature, are most strongly influenced by pressure gradient and Newtonian and shear-thickening fluids are less affected, respectively. Favorable pressure gradient will decelerate mean concentration rate of decrease and adverse pressure gradient acts the opposite. Moreover, a larger aspect ratio leads to slower descending rate of mean concentration in purely electroosmotic and pressure-assisted flows while in a pressure-opposed flow, the behavior might change depending on the strength of pressure gradient and the value of channel aspect ratio.<div>

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from IPython.display import Markdown

# %%
# Schematic geometry of the problem 
fig = plt.figure()
img = mpl.image.imread('My figs/Fig1.JPEG.jpg')

plt.imshow(img,interpolation='none')
plt.axis('off'); 
txt="A schematic geometry of a rectangular microreactor"
fig.text(0.8, -0.1, txt, ha='center', fontsize='16')
plt.tight_layout(rect=(0,0,1.5,1.5));
plt.show()

# %%
# Cross section of the microreactor
fig = plt.figure()
img = mpl.image.imread('My figs/Fig2.JPEG.jpg')

plt.imshow(img,interpolation='none')
plt.axis('off'); 
txt="Cross section of the microreactor with the coordinate system"
fig.text(0.8, -0.1, txt, ha='center', fontsize='16')
plt.tight_layout(rect=(0,0,1.5,1.5));
plt.show()

# %%
# Velocity profiles


img1 = mpl.image.imread('My figs/Fig6_1.JPEG.jpg')
img2 = mpl.image.imread('My figs/Fig6_2.JPEG.jpg')


f, (ax1, ax2) = plt.subplots(1, 2, sharex=False, sharey=False)

for i,ax in enumerate(f.axes):
    ax1.axis('off'); 
    ax2.axis('off');
    ax1.imshow(img1,interpolation='hermite')
    ax2.imshow(img2,interpolation='hermite')
    f.tight_layout(rect=(0,0,2,2));
txt="Velocity profiles for both shearthining (left) and shearthickening (right) fluids in pure electroosmotic flow"
f.text(0.9, 0.4, txt, ha='center', fontsize='16')
plt.show()

# %%
# Velocity profiles


img1 = mpl.image.imread('My figs/Fig6_3.JPEG.jpg')
img2 = mpl.image.imread('My figs/Fig6_4.JPEG.jpg')


f, (ax1, ax2) = plt.subplots(1, 2, sharex=False, sharey=False)

for i,ax in enumerate(f.axes):
    ax1.axis('off'); 
    ax2.axis('off');
    ax1.imshow(img1,interpolation='hermite')
    ax2.imshow(img2,interpolation='hermite')
    f.tight_layout(rect=(0,0,2,2));
txt="Velocity profiles for both shearthining (left) and shearthickening (right) fluids in pressure assisted flow"
f.text(0.9, 0.4, txt, ha='center', fontsize='16')
plt.show()

# %%
# Velocity profiles


img1 = mpl.image.imread('My figs/Fig6_5.JPEG.jpg')
img2 = mpl.image.imread('My figs/Fig6_6.JPEG.jpg')


f, (ax1, ax2) = plt.subplots(1, 2, sharex=False, sharey=False)

for i,ax in enumerate(f.axes):
    ax1.axis('off'); 
    ax2.axis('off');
    ax1.imshow(img1,interpolation='hermite')
    ax2.imshow(img2,interpolation='hermite')
    f.tight_layout(rect=(0,0,2,2));
txt="Velocity profiles for both shearthining (left) and shearthickening (right) fluids in pressure opposed flow"
f.text(0.9, 0.4, txt, ha='center', fontsize='16')
plt.show()

# %% [markdown]
# ###  <div style="text-align: justify"> **_Shear-thinning fluids are more considerably influenced by flow driving forces than shear-thickening fluids for all cases_**</div>

# %% [markdown]
# ### <div style="text-align: center"> Pe Number: A comparison between convective and diffusive transports <div>

# %%
### Creating a sample plot from datas available for mean concentration of the solute as a function of Pe number

fig, ax1 = plt.subplots()
ax1.yaxis.set_ticks_position('both')

data1 = np.loadtxt('My data/Shearthining_pressure opposed/C_meanPe1.dat',skiprows=3)
data2 = np.loadtxt('My data/Shearthining_pressure opposed/C_meanPe10.dat',skiprows=3)
data3 = np.loadtxt('My data/Shearthining_pressure opposed/C_meanPe100.dat',skiprows=3)
x= data1[:,0]
mean_concentration1=data1[:,1]
mean_concentration2=data2[:,1]
mean_concentration3=data3[:,1]

plt.plot(x, mean_concentration1, lw=2, color='k',ls='--',label='Pe=1')
plt.plot(x, mean_concentration2, lw=2, color='c',ls='-',label='Pe=10')
plt.plot(x, mean_concentration3, lw=2, color='m',ls='-.',label='Pe=100')
plt.legend(loc='upper right',markerfirst=False,title='',frameon=True,shadow=True,fancybox=True, fontsize='x-large')
plt.xlabel('x', fontsize='xx-large');
plt.ylabel('Mean concentration',fontsize='xx-large')
plt.xlim(0,30);
plt.ylim(0,1);
plt.tight_layout(rect=(0,0,1.5,1.5));
txt="Variation of the mean concentration of the solute along the microreactor for a shearthining fluid in pressure opposed flow"
fig.text(0.8, -0.1, txt, ha='center', fontsize=16)
plt.show()

# %%
### Creating a sample plot from datas available for mean concentration of the solute as a function of Pe number

fig, ax1 = plt.subplots()
ax1.yaxis.set_ticks_position('both')

data1 = np.loadtxt('My data/Shearthickening_pressure opposed/C_meanPe1.dat',skiprows=3)
data2 = np.loadtxt('My data/Shearthickening_pressure opposed/C_meanPe10.dat',skiprows=3)
data3 = np.loadtxt('My data/Shearthickening_pressure opposed/C_meanPe100.dat',skiprows=3)
x= data1[:,0]
mean_concentration1=data1[:,1]
mean_concentration2=data2[:,1]
mean_concentration3=data3[:,1]

plt.plot(x, mean_concentration1, lw=2, color='k',ls='--',label='Pe=1')
plt.plot(x, mean_concentration2, lw=2, color='c',ls='-',label='Pe=10')
plt.plot(x, mean_concentration3, lw=2, color='m',ls='-.',label='Pe=100')
plt.legend(loc='upper right',markerfirst=False,title='',frameon=True,shadow=True,fancybox=True, fontsize='x-large')
plt.xlabel('x', fontsize='xx-large');
plt.ylabel('Mean concentration',fontsize='xx-large')
plt.xlim(0,30);
plt.ylim(0,1);
plt.tight_layout(rect=(0,0,1.5,1.5));
txt="Variation of the mean concentration of the solute along the microreactor for a shearthickening fluid in pressure opposed flow"
fig.text(0.8, -0.1, txt, ha='center', fontsize=16)
plt.show()

# %% [markdown]
# ### <div style="text-align: center"> Da Number: A comparison of consumption of reactants by reaction and diffusion <div>

# %%
### Creating a sample plot from datas available for mean concentration of the solute as a function of Da number

fig, ax1 = plt.subplots()
ax1.yaxis.set_ticks_position('both')

data1 = np.loadtxt('My data/Shearthining_pressure assisted/C_meanDa1d.dat',skiprows=3)
data2 = np.loadtxt('My data/Shearthining_pressure assisted/C_meanDa5d.dat',skiprows=3)
data3 = np.loadtxt('My data/Shearthining_pressure assisted/C_meanDa5.dat',skiprows=3)
data4 = np.loadtxt('My data/Shearthining_pressure assisted/C_meanDa10000.dat',skiprows=3)
x= data1[:,0]
mean_concentration1=data1[:,1]
mean_concentration2=data2[:,1]
mean_concentration3=data3[:,1]
mean_concentration4=data4[:,1]

plt.plot(x, mean_concentration1, lw=2, color='k',ls='--',label='Da=0.1')
plt.plot(x, mean_concentration2, lw=2, color='c',ls='-',label='Da=0.5')
plt.plot(x, mean_concentration3, lw=2, color='m',ls='-.',label='Da=5')
plt.plot(x, mean_concentration4, lw=2, color='g',ls=':',label='Da=10000')
plt.legend(loc='upper right',markerfirst=False,title='',frameon=True,shadow=True,fancybox=True, fontsize='x-large')
plt.xlabel('x', fontsize='xx-large');
plt.ylabel('Mean concentration',fontsize='xx-large')
plt.xlim(0,30);
plt.ylim(0,1);
plt.tight_layout(rect=(0,0,1.5,1.5));
txt="Variation of the mean concentration of the solute along the microreactor for a shearthining fluid in pressure assisted flow"
fig.text(0.8, -0.1, txt, ha='center', fontsize=16)
plt.show()

# %%
### Creating a sample plot from datas available for mean concentration of the solute as a function of Da number



fig, ax1 = plt.subplots()
ax1.yaxis.set_ticks_position('both')

data1 = np.loadtxt('My data/Shearthickening_pressure assisted/C_meanDa1d.dat',skiprows=3)
data2 = np.loadtxt('My data/Shearthickening_pressure assisted/C_meanDa5d.dat',skiprows=3)
data3 = np.loadtxt('My data/Shearthickening_pressure assisted/C_meanDa5.dat',skiprows=3)
data4 = np.loadtxt('My data/Shearthickening_pressure assisted/C_meanDa10000.dat',skiprows=3)
x= data1[:,0]
mean_concentration1=data1[:,1]
mean_concentration2=data2[:,1]
mean_concentration3=data3[:,1]
mean_concentration4=data4[:,1]

plt.plot(x, mean_concentration1, lw=2, color='k',ls='--',label='Da=0.1')
plt.plot(x, mean_concentration2, lw=2, color='c',ls='-',label='Da=0.5')
plt.plot(x, mean_concentration3, lw=2, color='m',ls='-.',label='Da=5')
plt.plot(x, mean_concentration4, lw=2, color='g',ls=':',label='Da=10000')
plt.legend(loc='upper right',markerfirst=False,title='',frameon=True,shadow=True,fancybox=True, fontsize='x-large')
plt.xlabel('x', fontsize='xx-large');
plt.ylabel('Mean concentration',fontsize='xx-large')
plt.xlim(0,30);
plt.ylim(0,1);
plt.tight_layout(rect=(0,0,1.5,1.5));
txt="Variation of the mean concentration of the solute along the microreactor for a shearthickening fluid in pressure assisted flow"
fig.text(0.8, -0.1, txt, ha='center', fontsize=16)
plt.show()

# %% [markdown]
# ### Conclusion
#
# <div style="text-align: justify"> By means of a central finite difference numerical method, mass transfer of power-law fluids under combined electroosmotically and pressure driven flow in rectangular microreactors was studied in this paper. The present work is not limited with the assumption that axial concentration gradient in the microreactor is constant.Both mass axial and horizontal diffusions were taken into account.The velocity profile obtained by solving continuity and Cauchy momentum equations numerically is considered in the present study instead of an average axial velocity. A parametric study was performed to explore the effects of flow parameters on mean concentration. The results show that mean concentration is an increasing function of Péclet number and dimensionless Debye-Hückel parameter. Also, it decreases with increasing Damkohler number. In all cases, favorable pressure gradient slows down the descending trend of mean concentration while adverse pressure gradient does the opposite. In addition, when Gamma is positive, mean concentration decreases most gradually for shear-thinning fluids and after that are Newtonian and shear-thickening fluids, respectively. The reverse fashion is seen at negative values of Gamma. Increasing channel aspect ratio leads to slower decreasing rate of mean concentration through the microreactor in the case of favorable pressure gradient and purely electroosmotic flow. In the case of adverse pressure gradient, the behavior is not predictable from the beginning.<div>
